# %% [markdown]
# # Chapter 3 - 3.1 - 3.2

# %% [markdown]
# ## 3.1.1 Prerequisites

# %%
# Imports
import pandas as pd   
import altair as alt

# %% [markdown]
# ## 3.1.2 Altair data management

# %%
# I'm not quite sure what this line below is for.
# alt.data_transformers.enable('json')

# %% [markdown]
# ## 3.2.1 The mpg data frame

# %%
# Read in and display the data
url = "https://github.com/byuidatascience/data4python4ds/raw/master/data-raw/mpg/mpg.csv"
mpg = pd.read_csv(url)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %% [markdown]
# ## 3.2.2 Creating an Altair plot

# %%
displ_vs_hwy = (alt.Chart(mpg)
  .encode(
    x='displ', 
    y='hwy')
  .mark_circle()
)

displ_vs_hwy
# Out:
# alt.Chart(...)

# %% [markdown]
# ## 3.2.3 A graphing template

# %%
# Is this just for the future?

# (alt.Chart(<DATA>)  
#    .encode(<ENCODINGS>)
#     <.mark_*()>)

# %% [markdown]
# ## 3.2.4 Exercises

# %% [markdown]
# ### Question 1 - Run Chart(mpg).mark_point(). What do you see?

# %%
chartName = alt.Chart(mpg).mark_point()
chartName
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Question 2 - How many rows are in mpg? How many columns?

# %%
mpg.shape # 234 x 11
# Out:
# (234, 11)

# %% [markdown]
# ### Question 3 - What does the `drv` variable describe?

# %% [markdown]
# * According to the [data](https://github.com/byuidatascience/data4python4ds/blob/master/data.md#fuel-economy-data-from-1999-to-2008-for-38-popular-models-of-cars), `drv` means "the type of drive train, where f = front-wheel drive, r = rear wheel drive, 4 = 4wd"

# %%
# A random sample of 10
mpg['drv'].sample(10)
# Out:
# 150    4
# 163    4
# 157    f
# 165    4
# 186    f
# 42     f
# 28     4
# 106    f
# 144    f
# 154    f
# Name: drv, dtype: object

# %% [markdown]
# ### Question 4 - Make a scatterplot of `hwy` vs `cyl`.

# %%
hwy_vs_cyl_chart = alt.Chart(mpg).encode(x="cyl", y="hwy").mark_circle()
hwy_vs_cyl_chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Question 5 - What happens if you make a scatterplot of `class` vs `drv`? Why is the plot not useful?

# %% [markdown]
# * The plot has nothing to prove regarding the hypothesis that "cars with big engines use more fuel."

# %%
class_vs_drv_chart = alt.Chart(mpg).encode(x="class", y="drv").mark_circle()
class_vs_drv_chart
# Out:
# alt.Chart(...)
